# %%
import numpy as np
import pandas as pd

df_TCS = pd.read_csv(r'D:\ShareData\TCS - Copy.csv',index_col=0)
df_Rel = pd.read_csv(r'D:\ShareData\Reliance.csv')

df_TCS.head()
# Out:
#            OpenPrice  High Price  Low Price   Close Price
# Date
# 27-Mar-20    1820.00     1850.00    1750.40       1824.50
# 26-Mar-20    1831.60     1832.05    1722.55       1790.95
# 25-Mar-20    1700.00     1810.00    1680.00       1750.30
# 24-Mar-20    1653.05     1770.00    1632.85       1703.15
# 23-Mar-20    1620.00     1750.00    1617.75       1669.70

# %%
df_TCS['OpenPrice'].plot.hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

df_TCS['OpenPrice'].plot.hist()

# %%
df_TCS.plot.area(alpha=0.4)

# %%
df_TCS.head().plot.bar()

# %%
df_TCS.head().plot.bar(stacked=True)
